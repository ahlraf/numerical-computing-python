# %%
import numpy as np
import pprint as pp

# %% [markdown]
# Defining matrix A and tolerance

# %%
A = np.array([[-30.,10.,20.],[10.,40.,-50.],[20.,-50.,-10.]])
n = len(A)
tolerance = 1E-9

# %% [markdown]
# Helper function that calculates eigenvalues - (Rayleigh's quotient)

# %%
def eigenvalue(A,v):
    Av = A.dot(v)
    return v.dot(Av)/v.dot(v)

# %% [markdown]
# ### Power method for finding the largest eigenvalue

# %%
def power_iteration(A):
    """
    Converges to eigenvalue farthest from zero and associated eigenvector.
    Procedure:
    1. Let v be an approximation to x1 (random vector of unit magnitude)
    2. Compute vector z = Av
    3. Compute |z|
    4. Let v = z/|z| and repeat 2-4 until change in v is negligible.
    """
    n,d = A.shape
    v = np.ones(d) / np.sqrt(d)
    ev = eigenvalue(A,v)
    
    iteration = 1
    while True:
        Av = A.dot(v)
        v_new = Av / np.linalg.norm(Av)
        
        ev_new = eigenvalue(A,v_new)
        if np.abs(ev - ev_new) < tolerance:
            break
        print("Iteration #:",iteration)
        print("Eigenvalue:","%.6f"%ev_new)
        print("Eigenvector:",end=' ')
        pp.pprint(v_new)
        print('\n')
        v = v_new
        ev = ev_new
        iteration += 1
        
    print("\n\nLargest eigenvalue: %.6f"%ev_new)
    print("Took %d iterations"%(iteration-1))
    return ev_new, v_new

# %%
_eigenvalue, _eigenvector = power_iteration(A)
# Out:
# Iteration #: 1
# Eigenvalue: -10.000000
# Eigenvector: array([ 0.,  0., -1.])
#
#
# Iteration #: 2
# Eigenvalue: 3.000000
# Eigenvector: array([-0.36514837,  0.91287093,  0.18257419])
#
#
# Iteration #: 3
# Eigenvalue: 15.726979
# Eigenvector: array([ 0.36947327,  0.36947327, -0.85263063])
#
#
# Iteration #: 4
# Eigenvalue: 27.577558
# Eigenvector: array([-0.37111048,  0.9277762 , -0.03883714])
#
#
# Iteration #: 5
# Eigenvalue: 38.004319
# Eigenvector: array([ 0.29306512,  0.52751722, -0.79739477])
#
#
# Iteration #: 6
# Eigenvalue: 46.632560
# Eigenvector: array([-0.28638499,  0.94018052, -0.18451078])
#
#
# Iteration #: 7
# Eigenvalue: 53.411719
# Eigenvector: array([ 0.2080184 ,  0.63946397, -0.7401447 ])
#
#
# Iteration #: 8
# Eigenvalue: 58.524038
# Eigenvector: array([-0.21115374,  0.93212122, -0.29421783])
#
#
# Iteration #: 9
# Eigenvalue: 62.261356
# Eigenvector: array([ 0.13992008,  0.71430432, -0.68570527])
#
#
# Iteration #: 10
# Eigenvalue: 64.931852
# Eigenvector: array([-0.15346284,  0.915713  , -0.37137428])
#
#
# Iteration #: 11
# Eigenvalue: 66.809089
# Eigenvector: array([ 0.08995263,  0.76214886, -0.64112218])
#
#
# Iteration #: 12
# Eigenvalue: 68.113577
# Eigenvector: array([-0.11192826,  0.89890202, -0.42361211])
#
#
# Iteration #: 13
# Eigenvalue: 69.012819
# Eigenvector: array([ 0.05480944,  0.7924075 , -0.60752471])
#
#
# Iteration #: 14
# Eigenvalue: 69.629283
# Eigenvector: array([-0.08295179,  0.88481627, -0.45849665])
#
#
# Iteration #: 15
# Eigenvalue: 70.050289
# Eigenvector: array([ 0.03059257,  0.81166603, -0.58332012])
#
#
# Iteration #: 16
# Eigenvalue: 70.337064
# Eigenvector: array([-0.06304319,  0.87404336, -0.48174035])
#
#
# Iteration #: 17
# Eigenvalue: 70.532060
# Eigenvector: array([ 0.01406298,  0.82407215, -0.56631027])
#
#
# Iteration #: 18
# Eigenvalue: 70.664491
# Eigenvector: array([-0.04946436,  0.86619043, -0.49725991])
#
#
# Iteration #: 19
# Eigenvalue: 70.754356
# Eigenvector: array([ 0.00282911,  0.83216259, -0.5545245 ])
#
#
# Iteration #: 20
# Eigenvalue: 70.815304
# Eigenvector: array([-0.04023499,  0.86062058, -0.50765477])
#
#
# Iteration #: 21
# Eigenvalue: 70.856624
# Eigenvector: array([-0.00479105,  0.83749355, -0.5464262 ])
#
#
# Iteration #: 22
# Eigenvalue: 70.884631
# Eigenvector: array([-0.03397237,  0.85673444, -0.51463771])
#
#
# Iteration #: 23
# Eigenvalue: 70.903609
# Eigenvector: array([-0.00995568,  0.84103453, -0.54088983])
#
#
# Iteration #: 24
# Eigenvalue: 70.916469
# Eigenvector: array([-0.02972628,  0.85405066, -0.51933979])
#
#
# Iteration #: 25
# Eigenvalue: 70.925182
# Eigenvector: array([-0.01345484,  0.84340049, -0.53711691])
#
#
# Iteration #: 26
# Eigenvalue: 70.931085
# Eigenvector: array([-0.02684858,  0.85220931, -0.52251168])
#
#
# Iteration #: 27
# Eigenvalue: 70.935084
# Eigenvector: array([-0.01582528,  0.84498807, -0.53455095])
#
#
# Iteration #: 28
# Eigenvalue: 70.937794
# Eigenvector: array([-0.02489867,  0.85095131, -0.5246541 ])
#
#
# Iteration #: 29
# Eigenvalue: 70.939629
# Eigenvector: array([-0.01743102,  0.84605652, -0.53280815])
#
#
# Iteration #: 30
# Eigenvalue: 70.940872
# Eigenvector: array([-0.02357757,  0.85009426, -0.52610251])
#
#
# Iteration #: 31
# Eigenvalue: 70.941714
# Eigenvector: array([-0.01851875,  0.84677708, -0.53162546])
#
#
# Iteration #: 32
# Eigenvalue: 70.942285
# Eigenvector: array([-0.02268256,  0.84951146, -0.52708234])
#
#
# Iteration #: 33
# Eigenvalue: 70.942672
# Eigenvector: array([-0.01925557,  0.84726372, -0.53082334])
#
#
# Iteration #: 34
# Eigenvalue: 70.942933
# Eigenvector: array([-0.02207622,  0.84911564, -0.52774547])
#
#
# Iteration #: 35
# Eigenvalue: 70.943111
# Eigenvector: array([-0.0197547 ,  0.84759269, -0.53027953])
#
#
# Iteration #: 36
# Eigenvalue: 70.943231
# Eigenvector: array([-0.02166546,  0.84884703, -0.5281944 ])
#
#
# Iteration #: 37
# Eigenvalue: 70.943312
# Eigenvector: array([-0.02009281,  0.84781523, -0.52991095])
#
#
# Iteration #: 38
# Eigenvalue: 70.943368
# Eigenvector: array([-0.0213872 ,  0.84866486, -0.52849838])
#
#
# Iteration #: 39
# Eigenvalue: 70.943405
# Eigenvector: array([-0.02032185,  0.84796584, -0.52966117])
#
#
# Iteration #: 40
# Eigenvalue: 70.943430
# Eigenvector: array([-0.0211987 ,  0.84854136, -0.52870425])
#
#
# Iteration #: 41
# Eigenvalue: 70.943447
# Eigenvector: array([-0.02047701,  0.8480678 , -0.52949193])
#
#
# Iteration #: 42
# Eigenvalue: 70.943459
# Eigenvector: array([-0.021071  ,  0.84845765, -0.52884368])
#
#
# Iteration #: 43
# Eigenvalue: 70.943467
# Eigenvector: array([-0.02058212,  0.84813684, -0.52937726])
#
#
# Iteration #: 44
# Eigenvalue: 70.943472
# Eigenvector: array([-0.0209845 ,  0.84840092, -0.52893811])
#
#
# Iteration #: 45
# Eigenvalue: 70.943476
# Eigenvector: array([-0.02065332,  0.84818359, -0.52929957])
#
#
# Iteration #: 46
# Eigenvalue: 70.943478
# Eigenvector: array([-0.0209259 ,  0.84836248, -0.52900208])
#
#
# Iteration #: 47
# Eigenvalue: 70.943480
# Eigenvector: array([-0.02070155,  0.84821526, -0.52924694])
#
#
# Iteration #: 48
# Eigenvalue: 70.943481
# Eigenvector: array([-0.0208862 ,  0.84833644, -0.52904541])
#
#
# Iteration #: 49
# Eigenvalue: 70.943482
# Eigenvector: array([-0.02073422,  0.8482367 , -0.52921129])
#
#
# Iteration #: 50
# Eigenvalue: 70.943482
# Eigenvector: array([-0.02085931,  0.8483188 , -0.52907477])
#
#
# Iteration #: 51
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02075635,  0.84825123, -0.52918713])
#
#
# Iteration #: 52
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02084109,  0.84830684, -0.52909465])
#
#
# Iteration #: 53
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02077135,  0.84826107, -0.52917077])
#
#
# Iteration #: 54
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02082875,  0.84829875, -0.52910812])
#
#
# Iteration #: 55
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02078151,  0.84826774, -0.52915968])
#
#
# Iteration #: 56
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02082039,  0.84829326, -0.52911724])
#
#
# Iteration #: 57
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02078839,  0.84827226, -0.52915217])
#
#
# Iteration #: 58
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02081473,  0.84828954, -0.52912342])
#
#
# Iteration #: 59
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02079305,  0.84827532, -0.52914709])
#
#
# Iteration #: 60
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02081089,  0.84828703, -0.52912761])
#
#
# Iteration #: 61
# Eigenvalue: 70.943483
# Eigenvector: array([-0.0207962 ,  0.84827739, -0.52914364])
#
#
# Iteration #: 62
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02080829,  0.84828532, -0.52913045])
#
#
# Iteration #: 63
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02079834,  0.84827879, -0.52914131])
#
#
# Iteration #: 64
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02080653,  0.84828417, -0.52913237])
#
#
# Iteration #: 65
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02079979,  0.84827974, -0.52913972])
#
#
# Iteration #: 66
# Eigenvalue: 70.943483
# Eigenvector: array([-0.02080534,  0.84828338, -0.52913367])
#
#
#
#
# Largest eigenvalue: 70.943483
# Took 66 iterations

# %%
print("Largest eigenvalue: %.6f"%_eigenvalue)
# Out:
# Largest eigenvalue: 70.943483

# %% [markdown]
# Thus, the **power method** took 66 iterations to converge to the largest eigenvalue, 70.943483, for given tolerance

# %% [markdown]
# <br><br>
# ### Inverse power method for finding smallest eigenvalue

# %% [markdown]
# Implementing helper LU decomposition functions

# %%
def LUdecomp(a):
    """
    a = LUdecomp(a)
    LU decomposition: [L][U] = [a]
    The returned matrix [a] = [L-U] contains [U] in the upper triangle and 
    the nondiagonal terms of [L] in the lower triangle.
    """
    n = len(a)
    for k in range(0,n-1):
        for i in range(k+1,n):
            if a[i,k] != 0.0:
                lam = a[i,k]/a[k,k]
                a[i,k+1:n] = a[i,k+1:n] - lam*a[k,k+1:n]
                a[i,k] = lam
    return a

def LUsolve(a,b):
    """x = LUsolve(a,b)
    Solves [L][U]{x} = b, 
    where [a] = [L\\U] is the matrix returnedfrom LUdecomp
    """
    n = len(a)
    for k in range(1,n):
        b[k] = b[k] - np.dot(a[k,0:k],b[0:k])
    for k in range(n-1,-1,-1):
        b[k] = (b[k] - np.dot(a[k,k+1:n],b[k+1:n]))/a[k,k]
    return b

# %% [markdown]
# Inverse power method implementation

# %%
from math import sqrt
from random import random

def inverse_power(a,s,maxIter,tol=1E-9):
    """
    Inverse power method for solving the eigenvalue problem 
    [a]{x} = lam{x}.
    Returns 'lam' closest to 's' and the corresponding eigenvector {x}
    's' allows the method of eigenvalue shifting - corresponding convergence
    is much faster.
    """
    n = len(a)
    
    #form [a*] = [a] - s[I]
    a_star = a - np.identity(n)*s
    #decompose [a*]
    a_star = LUdecomp(a_star)
    
    x = np.zeros((n),dtype=float)
    
    #seed [x] with random numbers
    for i in range(n):
        x[i] = random()
    
    #normalize [x]
    x_mag = np.linalg.norm(x)
    x = x/x_mag
    
    for i in range(maxIter):
        #save current x
        x_old = np.copy(x)
        #solve [a*][x] = [xOld]
        x = LUsolve(a_star,x)
        
        #normalize [x]
        x_mag = np.linalg.norm(x)
        
        x = x/x_mag
        
        #detect change in sign of [x]
        if np.dot(x_old,x)<0.0:
            sign = -1.0
            x = -x
        else:
            sign = 1.0
        
        print('Iteration #',i+1)
        print('Eigenvalue: %.6f'%(s+sign/x_mag))
        print('Eigenvector:',end=' ')
        pp.pprint(x)
        print('\n')
        
        if np.linalg.norm(x_old-x) < tol:
            return s+sign/x_mag, x
    
    print('Inverse power method did not converge')

# %%
small_eval,s_evector = inverse_power(A,0,100)
# Out:
# Iteration # 1
# Eigenvalue: -17.181693
# Eigenvector: array([0.64823358, 0.37626692, 0.66197918])
#
#
# Iteration # 2
# Eigenvalue: -12.808236
# Eigenvector: array([0.75841768, 0.36493864, 0.54002076])
#
#
# Iteration # 3
# Eigenvalue: -12.564789
# Eigenvector: array([0.78043842, 0.3433804 , 0.52249954])
#
#
# Iteration # 4
# Eigenvalue: -12.553583
# Eigenvector: array([0.7849763 , 0.34183937, 0.51667984])
#
#
# Iteration # 5
# Eigenvalue: -12.553070
# Eigenvector: array([0.78595991, 0.34094776, 0.51577286])
#
#
# Iteration # 6
# Eigenvalue: -12.553047
# Eigenvector: array([0.78616869, 0.34085467, 0.51551613])
#
#
# Iteration # 7
# Eigenvalue: -12.553046
# Eigenvector: array([0.78621399, 0.34081718, 0.51547183])
#
#
# Iteration # 8
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622366, 0.34081221, 0.51546037])
#
#
# Iteration # 9
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622575, 0.3408106 , 0.51545825])
#
#
# Iteration # 10
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622619, 0.34081035, 0.51545774])
#
#
# Iteration # 11
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622629, 0.34081028, 0.51545764])
#
#
# Iteration # 12
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622631, 0.34081027, 0.51545761])
#
#
# Iteration # 13
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622632, 0.34081026, 0.51545761])
#
#
# Iteration # 14
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622632, 0.34081026, 0.51545761])
#
#
# Iteration # 15
# Eigenvalue: -12.553046
# Eigenvector: array([0.78622632, 0.34081026, 0.51545761])

# %%
print("Smallest eigenvalue using inverse power iterations: %.6f"%small_eval)
print("Corresponding eigenvector:")
pp.pprint(s_evector)
# Out:
# Smallest eigenvalue using inverse power iterations: -12.553046
# Corresponding eigenvector:
# array([0.78622632, 0.34081026, 0.51545761])

# %% [markdown]
# Therefore, **inverse power method** took 15 iterations to converge to the smallest eigenvalue, -12.553046, for given tolerance

# %% [markdown]
# *Pentadiagonal matrix example*

# %% [markdown]
# Generating matrix from 3 smaller matrices a, b, c

# %%
def pentadiag(a,b,c):
    return np.diag(a,-2) + np.diag(b,-1) + np.diag(c,0) + np.diag(b,1) + np.diag(a,2)

a = np.ones((8),dtype=int)
b = 2*np.ones((9),dtype=int)
c = 4*np.ones((10),dtype=int)
A2 = pentadiag(a,b,c)
A2
# Out:
# array([[4, 2, 1, 0, 0, 0, 0, 0, 0, 0],
#        [2, 4, 2, 1, 0, 0, 0, 0, 0, 0],
#        [1, 2, 4, 2, 1, 0, 0, 0, 0, 0],
#        [0, 1, 2, 4, 2, 1, 0, 0, 0, 0],
#        [0, 0, 1, 2, 4, 2, 1, 0, 0, 0],
#        [0, 0, 0, 1, 2, 4, 2, 1, 0, 0],
#        [0, 0, 0, 0, 1, 2, 4, 2, 1, 0],
#        [0, 0, 0, 0, 0, 1, 2, 4, 2, 1],
#        [0, 0, 0, 0, 0, 0, 1, 2, 4, 2],
#        [0, 0, 0, 0, 0, 0, 0, 1, 2, 4]])

# %% [markdown]
# **Largest eigenvalue, using power method**

# %%
_eigenvalue2, _eigenvector2 = power_iteration(A2)
# Out:
# Iteration #: 1
# Eigenvalue: 9.423256
# Eigenvector: array([0.23869802, 0.30689745, 0.34099717, 0.34099717, 0.34099717,
#        0.34099717, 0.34099717, 0.34099717, 0.30689745, 0.23869802])
#
#
# Iteration #: 2
# Eigenvalue: 9.495542
# Eigenvector: array([0.20217265, 0.28881807, 0.34297146, 0.35741237, 0.36102259,
#        0.36102259, 0.35741237, 0.34297146, 0.28881807, 0.20217265])
#
#
# Iteration #: 3
# Eigenvalue: 9.526969
# Eigenvector: array([0.18193768, 0.27385609, 0.33956636, 0.36691398, 0.37678952,
#        0.37678952, 0.36691398, 0.33956636, 0.27385609, 0.18193768])
#
#
# Iteration #: 4
# Eigenvalue: 9.541698
# Eigenvector: array([0.16944427, 0.26285381, 0.33558095, 0.37256221, 0.38830315,
#        0.38830315, 0.37256221, 0.33558095, 0.26285381, 0.16944427])
#
#
# Iteration #: 5
# Eigenvalue: 9.548694
# Eigenvector: array([0.16126394, 0.25503846, 0.33224856, 0.37607514, 0.39639337,
#        0.39639337, 0.37607514, 0.33224856, 0.25503846, 0.16126394])
#
#
# Iteration #: 6
# Eigenvalue: 9.552019
# Eigenvector: array([0.15575198, 0.24956381, 0.32973664, 0.37833907, 0.40198572,
#        0.40198572, 0.37833907, 0.32973664, 0.24956381, 0.15575198])
#
#
# Iteration #: 7
# Eigenvalue: 9.553599
# Eigenvector: array([0.15198892, 0.24575501, 0.32792403, 0.37983308, 0.40582816,
#        0.40582816, 0.37983308, 0.32792403, 0.24575501, 0.15198892])
#
#
# Iteration #: 8
# Eigenvalue: 9.554349
# Eigenvector: array([0.14940512, 0.2431152 , 0.32664307, 0.38083401, 0.40846404,
#        0.40846404, 0.38083401, 0.32664307, 0.2431152 , 0.14940512])
#
#
# Iteration #: 9
# Eigenvalue: 9.554705
# Eigenvector: array([0.14762685, 0.24128968, 0.32574754, 0.38151102, 0.41027246,
#        0.41027246, 0.38151102, 0.32574754, 0.24128968, 0.14762685])
#
#
# Iteration #: 10
# Eigenvalue: 9.554873
# Eigenvector: array([0.14640191, 0.24002904, 0.32512514, 0.38197174, 0.41151401,
#        0.41151401, 0.38197174, 0.32512514, 0.24002904, 0.14640191])
#
#
# Iteration #: 11
# Eigenvalue: 9.554953
# Eigenvector: array([0.14555791, 0.23915925, 0.32469403, 0.38228652, 0.41236702,
#        0.41236702, 0.38228652, 0.32469403, 0.23915925, 0.14555791])
#
#
# Iteration #: 12
# Eigenvalue: 9.554991
# Eigenvector: array([0.14497638, 0.23855948, 0.32439603, 0.38250214, 0.41295346,
#        0.41295346, 0.38250214, 0.32439603, 0.23855948, 0.14497638])
#
#
# Iteration #: 13
# Eigenvalue: 9.555009
# Eigenvector: array([0.14457572, 0.23814606, 0.32419029, 0.3826501 , 0.41335683,
#        0.41335683, 0.3826501 , 0.32419029, 0.23814606, 0.14457572])
#
#
# Iteration #: 14
# Eigenvalue: 9.555018
# Eigenvector: array([0.14429969, 0.23786117, 0.32404837, 0.38275175, 0.4136344 ,
#        0.4136344 , 0.38275175, 0.32404837, 0.23786117, 0.14429969])
#
#
# Iteration #: 15
# Eigenvalue: 9.555022
# Eigenvector: array([0.14410955, 0.23766489, 0.32395052, 0.38282164, 0.41382544,
#        0.41382544, 0.38282164, 0.32395052, 0.23766489, 0.14410955])
#
#
# Iteration #: 16
# Eigenvalue: 9.555024
# Eigenvector: array([0.14397857, 0.23752967, 0.32388308, 0.38286972, 0.41395696,
#        0.41395696, 0.38286972, 0.32388308, 0.23752967, 0.14397857])
#
#
# Iteration #: 17
# Eigenvalue: 9.555025
# Eigenvector: array([0.14388835, 0.23743652, 0.3238366 , 0.3829028 , 0.41404751,
#        0.41404751, 0.3829028 , 0.3238366 , 0.23743652, 0.14388835])
#
#
# Iteration #: 18
# Eigenvalue: 9.555025
# Eigenvector: array([0.14382621, 0.23737236, 0.32380459, 0.38292558, 0.41410986,
#        0.41410986, 0.38292558, 0.32380459, 0.23737236, 0.14382621])
#
#
# Iteration #: 19
# Eigenvalue: 9.555025
# Eigenvector: array([0.14378341, 0.23732816, 0.32378253, 0.38294126, 0.4141528 ,
#        0.4141528 , 0.38294126, 0.32378253, 0.23732816, 0.14378341])
#
#
# Iteration #: 20
# Eigenvalue: 9.555026
# Eigenvector: array([0.14375393, 0.23729772, 0.32376734, 0.38295205, 0.41418237,
#        0.41418237, 0.38295205, 0.32376734, 0.23729772, 0.14375393])
#
#
# Iteration #: 21
# Eigenvalue: 9.555026
# Eigenvector: array([0.14373363, 0.23727676, 0.32375687, 0.38295949, 0.41420273,
#        0.41420273, 0.38295949, 0.32375687, 0.23727676, 0.14373363])
#
#
# Iteration #: 22
# Eigenvalue: 9.555026
# Eigenvector: array([0.14371965, 0.23726232, 0.32374966, 0.38296461, 0.41421676,
#        0.41421676, 0.38296461, 0.32374966, 0.23726232, 0.14371965])
#
#
# Iteration #: 23
# Eigenvalue: 9.555026
# Eigenvector: array([0.14371002, 0.23725237, 0.3237447 , 0.38296813, 0.41422641,
#        0.41422641, 0.38296813, 0.3237447 , 0.23725237, 0.14371002])
#
#
# Iteration #: 24
# Eigenvalue: 9.555026
# Eigenvector: array([0.14370338, 0.23724552, 0.32374128, 0.38297056, 0.41423307,
#        0.41423307, 0.38297056, 0.32374128, 0.23724552, 0.14370338])
#
#
# Iteration #: 25
# Eigenvalue: 9.555026
# Eigenvector: array([0.14369881, 0.2372408 , 0.32373892, 0.38297223, 0.41423765,
#        0.41423765, 0.38297223, 0.32373892, 0.2372408 , 0.14369881])
#
#
# Iteration #: 26
# Eigenvalue: 9.555026
# Eigenvector: array([0.14369567, 0.23723755, 0.3237373 , 0.38297339, 0.4142408 ,
#        0.4142408 , 0.38297339, 0.3237373 , 0.23723755, 0.14369567])
#
#
#
#
# Largest eigenvalue: 9.555026
# Took 26 iterations

# %%
print("Largest eigenvalue: %.6f"%_eigenvalue2)
# Out:
# Largest eigenvalue: 9.555026

# %% [markdown]
# Therefore, **power method** takes 26 iterations to obtain largest eigenvalue, 9.555026, for given tolerance.

# %% [markdown]
# <br>**Smallest eigenvalue, using inverse power method**

# %% [markdown]
# Running first with 0 shift, to get an estimate of smallest value

# %%
inverse_power(A2,0,100,tol=1E-6)
# Out:
# Iteration # 1
# Eigenvalue: 5.030621
# Eigenvector: array([ 0.5521873 ,  0.24011326, -0.37871251,  0.46730675,  0.34487649,
#         0.01764426,  0.36634706, -0.12739366,  0.07704822,  0.00303196])
#
#
# Iteration # 2
# Eigenvalue: 1.773540
# Eigenvector: array([ 0.33765539,  0.10420235, -0.57970023,  0.49313065,  0.11481791,
#        -0.31817328,  0.38216597, -0.18311247,  0.00882072,  0.04271208])
#
#
# Iteration # 3
# Eigenvalue: 1.329308
# Eigenvector: array([ 0.21175437,  0.07211066, -0.5423908 ,  0.51134725,  0.02029293,
#        -0.41778141,  0.42671577, -0.15718928, -0.06919839,  0.08809089])
#
#
# Iteration # 4
# Eigenvalue: 1.253878
# Eigenvector: array([ 0.15877645,  0.06100111, -0.49159388,  0.51204839, -0.01859177,
#        -0.44765639,  0.46262182, -0.13332977, -0.1348737 ,  0.1283831 ])
#
#
# Iteration # 5
# Eigenvalue: 1.227185
# Eigenvector: array([ 0.13640295,  0.05127466, -0.453313  ,  0.50358112, -0.0361393 ,
#        -0.45831629,  0.48452497, -0.11644467, -0.18471597,  0.16085662])
#
#
# Iteration # 6
# Eigenvalue: 1.215138
# Eigenvector: array([ 0.12706545,  0.04175683, -0.42602703,  0.49320165, -0.04371221,
#        -0.46316426,  0.49688687, -0.10381156, -0.22111882,  0.18537806])
#
#
# Iteration # 7
# Eigenvalue: 1.209152
# Eigenvector: array([ 0.12341872,  0.0332721 , -0.40657759,  0.4837197 , -0.04622357,
#        -0.46619262,  0.50356298, -0.09366423, -0.24750272,  0.203205  ])
#
#
# Iteration # 8
# Eigenvalue: 1.206023
# Eigenvector: array([ 0.12222945,  0.02630444, -0.39268085,  0.47581198, -0.04608079,
#        -0.46865202,  0.5069374 , -0.0851561 , -0.26674405,  0.21592852])
#
#
# Iteration # 9
# Eigenvalue: 1.204325
# Eigenvector: array([ 0.12202127,  0.02094927, -0.38277963,  0.46939874, -0.04451417,
#        -0.47092433,  0.50839125, -0.07786497, -0.28095481,  0.22495568])
#
#
# Iteration # 10
# Eigenvalue: 1.203370
# Eigenvector: array([ 0.12211019,  0.01709141, -0.37578684,  0.46419737, -0.0421659 ,
#        -0.47311509,  0.50871885, -0.07153909, -0.29161841,  0.2313702 ])
#
#
# Iteration # 11
# Eigenvalue: 1.202809
# Eigenvector: array([ 0.12218472,  0.01453068, -0.37092503,  0.4599156 , -0.0393769 ,
#        -0.47524848,  0.50838088, -0.06599669, -0.29976471,  0.23595506])
#
#
# Iteration # 12
# Eigenvalue: 1.202460
# Eigenvector: array([ 0.12211334,  0.01304948, -0.36763001,  0.45630801, -0.03633094,
#        -0.47732931,  0.50764721, -0.06109077, -0.30610985,  0.23925927])
#
#
# Iteration # 13
# Eigenvalue: 1.202228
# Eigenvector: array([ 0.12185198,  0.01244461, -0.36548909,  0.45318422, -0.03312829,
#        -0.47936061,  0.50667695, -0.05669765, -0.31115543,  0.24166316])
#
#
# Iteration # 14
# Eigenvalue: 1.202059
# Eigenvector: array([ 0.12139821,  0.01253978, -0.3641992 ,  0.45040201, -0.02982425,
#        -0.48134694,  0.50556392, -0.0527131 , -0.31525598,  0.24342958])
#
#
# Iteration # 15
# Eigenvalue: 1.201924
# Eigenvector: array([ 0.12076802,  0.01318831, -0.36353728,  0.44785713, -0.02644959,
#        -0.48329406,  0.50436303, -0.04905025, -0.31866445,  0.24474076])
#
#
# Iteration # 16
# Eigenvalue: 1.201809
# Eigenvector: array([ 0.11998404,  0.01427134, -0.36333882,  0.44547401, -0.02302164,
#        -0.48520793,  0.5031059 , -0.0456377 , -0.32156292,  0.24572377])
#
#
# Iteration # 17
# Eigenvalue: 1.201703
# Eigenvector: array([ 0.11906976,  0.01569426, -0.36348239,  0.44319814, -0.01955029,
#        -0.48709404,  0.50181019, -0.04241756, -0.32408347,  0.24646787])
#
#
# Iteration # 18
# Eigenvalue: 1.201602
# Eigenvector: array([ 0.11804684,  0.01738265, -0.36387818,  0.44099032, -0.01604134,
#        -0.48895701,  0.50048525, -0.03934339, -0.32632259,  0.24703623])
#
#
# Iteration # 19
# Eigenvalue: 1.201504
# Eigenvector: array([ 0.11693409,  0.01927851, -0.36445964,  0.43882238, -0.01249833,
#        -0.49080054,  0.49913555, -0.03637837, -0.32835111,  0.24747389])
#
#
# Iteration # 20
# Eigenvalue: 1.201406
# Eigenvector: array([ 0.11574723,  0.0213369 , -0.36517741,  0.43667408, -0.00892355,
#        -0.49262745,  0.49776279, -0.03349347, -0.3302213 ,  0.24781317])
#
#
# Iteration # 21
# Eigenvalue: 1.201308
# Eigenvector: array([ 0.11449913,  0.02352315, -0.36599476,  0.43453085, -0.00531861,
#        -0.49443977,  0.49636711, -0.03066605, -0.33197182,  0.24807741])
#
#
# Iteration # 22
# Eigenvalue: 1.201209
# Eigenvector: array([ 0.11320013,  0.02581059, -0.3668843 ,  0.4323822 , -0.00168475,
#        -0.49623888,  0.49494789, -0.0278785 , -0.33363137,  0.24828352])
#
#
# Iteration # 23
# Eigenvalue: 1.201109
# Eigenvector: array([ 0.11185844,  0.02817874, -0.36782553,  0.43022054,  0.00197701,
#        -0.49802566,  0.49350414, -0.02511727, -0.33522125,  0.24844385])
#
#
# Iteration # 24
# Eigenvalue: 1.201008
# Eigenvector: array([ 0.11048055,  0.03061189, -0.36880309,  0.42804042,  0.00566577,
#        -0.49980059,  0.49203476, -0.02237196, -0.33675726,  0.24856738])
#
#
# Iteration # 25
# Eigenvalue: 1.200906
# Eigenvector: array([ 0.10907155,  0.03309795, -0.3698054 ,  0.42583788,  0.00938066,
#        -0.50156382,  0.4905387 , -0.01963466, -0.33825113,  0.24866073])
#
#
# Iteration # 26
# Eigenvalue: 1.200802
# Eigenvector: array([ 0.10763544,  0.03562763, -0.37082369,  0.42361007,  0.01312087,
#        -0.5033153 ,  0.48901497, -0.0168994 , -0.33971155,  0.2487287 ])
#
#
# Iteration # 27
# Eigenvalue: 1.200697
# Eigenvector: array([ 0.10617534,  0.03819374, -0.37185128,  0.42135493,  0.0168856 ,
#        -0.50505477,  0.48746275, -0.0141617 , -0.3411449 ,  0.24877482])
#
#
# Iteration # 28
# Eigenvalue: 1.200591
# Eigenvector: array([ 0.10469369,  0.0407907 , -0.37288306,  0.41907098,  0.02067404,
#        -0.50678185,  0.48588132, -0.01141829, -0.34255586,  0.24880168])
#
#
# Iteration # 29
# Eigenvalue: 1.200483
# Eigenvector: array([ 0.10319244,  0.04341414, -0.37391506,  0.4167572 ,  0.02448539,
#        -0.50849608,  0.48427007, -0.00866676, -0.34394782,  0.24881114])
#
#
# Iteration # 30
# Eigenvalue: 1.200374
# Eigenvector: array([ 0.10167311,  0.04606063, -0.3749442 ,  0.41441286,  0.02831884,
#        -0.5101969 ,  0.48262853, -0.00590542, -0.34532319,  0.24880455])
#
#
# Iteration # 31
# Eigenvalue: 1.200264
# Eigenvector: array([ 0.10013694,  0.0487274 , -0.37596804,  0.41203749,  0.03217357,
#        -0.51188373,  0.48095632, -0.00313313, -0.34668367,  0.24878288])
#
#
# Iteration # 32
# Eigenvalue: 1.200152
# Eigenvector: array([ 9.85849346e-02,  5.14122258e-02, -3.76984629e-01,  4.09630779e-01,
#         3.60487415e-02, -5.13555923e-01,  4.79253128e-01, -3.49144929e-04,
#        -3.48030394e-01,  2.48746805e-01])
#
#
# Iteration # 33
# Eigenvalue: 1.200039
# Eigenvector: array([ 0.09701791,  0.05411325, -0.37799237,  0.40719259,  0.0399435 ,
#        -0.51521283,  0.47751874,  0.00244694, -0.34936409,  0.2486968 ])
#
#
# Iteration # 34
# Eigenvalue: 1.199925
# Eigenvector: array([ 0.09543659,  0.05682893, -0.37898995,  0.40472287,  0.04385699,
#        -0.51685377,  0.47575301,  0.00525527, -0.35068518,  0.24863317])
#
#
# Iteration # 35
# Eigenvalue: 1.199810
# Eigenvector: array([ 0.09384155,  0.05955793, -0.37997627,  0.40222166,  0.04778833,
#        -0.51847806,  0.47395583,  0.00807583, -0.35199385,  0.24855612])
#
#
# Iteration # 36
# Eigenvalue: 1.199694
# Eigenvector: array([ 0.09223335,  0.06229906, -0.38095037,  0.3996891 ,  0.0517366 ,
#        -0.52008501,  0.47212716,  0.01090841, -0.3532901 ,  0.24846577])
#
#
# Iteration # 37
# Eigenvalue: 1.199577
# Eigenvector: array([ 0.09061247,  0.06505127, -0.38191144,  0.39712536,  0.05570089,
#        -0.52167391,  0.470267  ,  0.01375272, -0.35457382,  0.24836216])
#
#
# Iteration # 38
# Eigenvalue: 1.199458
# Eigenvector: array([ 0.08897935,  0.06781359, -0.38285873,  0.39453067,  0.05968027,
#        -0.5232441 ,  0.46837541,  0.01660834, -0.3558448 ,  0.24824532])
#
#
# Iteration # 39
# Eigenvalue: 1.199339
# Eigenvector: array([ 0.08733444,  0.07058511, -0.38379159,  0.39190532,  0.06367377,
#        -0.52479486,  0.46645245,  0.01947481, -0.35710273,  0.24811522])
#
#
# Iteration # 40
# Eigenvalue: 1.199218
# Eigenvector: array([ 0.08567813,  0.07336497, -0.3847094 ,  0.38924963,  0.06768042,
#        -0.52632553,  0.46449826,  0.02235158, -0.35834729,  0.24797182])
#
#
# Iteration # 41
# Eigenvalue: 1.199097
# Eigenvector: array([ 0.08401083,  0.07615232, -0.38561161,  0.38656397,  0.07169923,
#        -0.52783544,  0.462513  ,  0.02523806, -0.3595781 ,  0.24781509])
#
#
# Iteration # 42
# Eigenvalue: 1.198974
# Eigenvector: array([ 0.08233295,  0.07894637, -0.3864977 ,  0.38384872,  0.0757292 ,
#        -0.52932392,  0.46049685,  0.02813364, -0.36079475,  0.24764496])
#
#
# Iteration # 43
# Eigenvalue: 1.198851
# Eigenvector: array([ 0.08064489,  0.0817463 , -0.38736718,  0.38110433,  0.0797693 ,
#        -0.53079032,  0.45845003,  0.03103765, -0.36199683,  0.24746137])
#
#
# Iteration # 44
# Eigenvalue: 1.198727
# Eigenvector: array([ 0.07894703,  0.08455134, -0.38821958,  0.37833125,  0.08381848,
#        -0.53223402,  0.4563728 ,  0.03394941, -0.36318391,  0.24726428])
#
#
# Iteration # 45
# Eigenvalue: 1.198602
# Eigenvector: array([ 0.07723979,  0.0873607 , -0.38905446,  0.37552999,  0.08787571,
#        -0.53365439,  0.45426544,  0.03686821, -0.36435557,  0.24705363])
#
#
# Iteration # 46
# Eigenvalue: 1.198477
# Eigenvector: array([ 0.07552359,  0.09017359, -0.38987141,  0.37270107,  0.09193991,
#        -0.53505082,  0.45212828,  0.03979333, -0.36551136,  0.24682937])
#
#
# Iteration # 47
# Eigenvalue: 1.198351
# Eigenvector: array([ 0.07379882,  0.09298924, -0.39067003,  0.36984504,  0.09601001,
#        -0.53642274,  0.44996164,  0.04272402, -0.36665086,  0.24659147])
#
#
# Iteration # 48
# Eigenvalue: 1.198224
# Eigenvector: array([ 0.07206593,  0.09580687, -0.39144994,  0.36696248,  0.10008493,
#        -0.53776957,  0.44776592,  0.04565953, -0.36777366,  0.2463399 ])
#
#
# Iteration # 49
# Eigenvalue: 1.198097
# Eigenvector: array([ 0.07032534,  0.09862569, -0.39221079,  0.36405401,  0.10416356,
#        -0.53909077,  0.4455415 ,  0.04859908, -0.36887933,  0.24607464])
#
#
# Iteration # 50
# Eigenvalue: 1.197969
# Eigenvector: array([ 0.06857748,  0.10144493, -0.39295223,  0.36112026,  0.1082448 ,
#        -0.54038582,  0.44328881,  0.0515419 , -0.36996747,  0.24579569])
#
#
# Iteration # 51
# Eigenvalue: 1.197840
# Eigenvector: array([ 0.0668228 ,  0.1042638 , -0.39367394,  0.35816189,  0.11232755,
#        -0.54165419,  0.44100833,  0.05448722, -0.3710377 ,  0.24550304])
#
#
# Iteration # 52
# Eigenvalue: 1.197711
# Eigenvector: array([ 0.06506175,  0.10708152, -0.39437562,  0.3551796 ,  0.11641069,
#        -0.54289542,  0.43870052,  0.05743422, -0.37208963,  0.24519671])
#
#
# Iteration # 53
# Eigenvalue: 1.197582
# Eigenvector: array([ 0.06329479,  0.10989731, -0.39505699,  0.35217408,  0.1204931 ,
#        -0.54410904,  0.43636591,  0.06038212, -0.37312289,  0.24487673])
#
#
# Iteration # 54
# Eigenvalue: 1.197453
# Eigenvector: array([ 0.06152238,  0.11271039, -0.39571777,  0.34914608,  0.12457366,
#        -0.54529462,  0.43400502,  0.06333012, -0.37413715,  0.24454313])
#
#
# Iteration # 55
# Eigenvalue: 1.197323
# Eigenvector: array([ 0.05974499,  0.11551997, -0.39635773,  0.34609635,  0.12865126,
#        -0.54645174,  0.43161842,  0.06627742, -0.37513206,  0.24419596])
#
#
# Iteration # 56
# Eigenvalue: 1.197193
# Eigenvector: array([ 0.05796309,  0.11832529, -0.39697663,  0.34302566,  0.13272477,
#        -0.54758003,  0.42920671,  0.06922321, -0.37610731,  0.24383529])
#
#
# Iteration # 57
# Eigenvalue: 1.197063
# Eigenvector: array([ 0.05617716,  0.12112556, -0.39757427,  0.33993483,  0.13679307,
#        -0.54867911,  0.42677048,  0.07216668, -0.3770626 ,  0.24346119])
#
#
# Iteration # 58
# Eigenvalue: 1.196933
# Eigenvector: array([ 0.05438768,  0.12392002, -0.39815046,  0.33682467,  0.14085506,
#        -0.54974867,  0.42431037,  0.07510703, -0.37799764,  0.24307374])
#
#
# Iteration # 59
# Eigenvalue: 1.196803
# Eigenvector: array([ 0.05259514,  0.1267079 , -0.39870503,  0.333696  ,  0.14490962,
#        -0.55078838,  0.42182705,  0.07804347, -0.37891218,  0.24267305])
#
#
# Iteration # 60
# Eigenvalue: 1.196673
# Eigenvector: array([ 0.05080002,  0.12948845, -0.39923783,  0.33054969,  0.14895565,
#        -0.55179798,  0.41932119,  0.0809752 , -0.37980597,  0.24225923])
#
#
# Iteration # 61
# Eigenvalue: 1.196543
# Eigenvector: array([ 0.04900282,  0.13226092, -0.39974874,  0.32738661,  0.15299206,
#        -0.55277722,  0.41679349,  0.08390142, -0.38067878,  0.2418324 ])
#
#
# Iteration # 62
# Eigenvalue: 1.196413
# Eigenvector: array([ 0.04720403,  0.13502456, -0.40023765,  0.32420763,  0.15701777,
#        -0.55372586,  0.41424466,  0.08682134, -0.38153041,  0.2413927 ])
#
#
# Iteration # 63
# Eigenvalue: 1.196283
# Eigenvector: array([ 0.04540414,  0.13777864, -0.40070447,  0.32101366,  0.1610317 ,
#        -0.55464373,  0.41167546,  0.08973419, -0.38236066,  0.24094027])
#
#
# Iteration # 64
# Eigenvalue: 1.196153
# Eigenvector: array([ 0.04360364,  0.14052244, -0.40114913,  0.31780561,  0.1650328 ,
#        -0.55553065,  0.40908662,  0.09263919, -0.38316938,  0.24047527])
#
#
# Iteration # 65
# Eigenvalue: 1.196024
# Eigenvector: array([ 0.04180303,  0.14325524, -0.4015716 ,  0.3145844 ,  0.16902001,
#        -0.55638648,  0.40647893,  0.09553557, -0.38395641,  0.23999787])
#
#
# Iteration # 66
# Eigenvalue: 1.195895
# Eigenvector: array([ 0.0400028 ,  0.14597634, -0.40197183,  0.31135096,  0.17299231,
#        -0.55721113,  0.40385316,  0.09842259, -0.38472164,  0.23950826])
#
#
# Iteration # 67
# Eigenvalue: 1.195767
# Eigenvector: array([ 0.03820343,  0.14868507, -0.40234984,  0.30810623,  0.17694868,
#        -0.5580045 ,  0.40121014,  0.1012995 , -0.38546494,  0.23900661])
#
#
# Iteration # 68
# Eigenvalue: 1.195639
# Eigenvector: array([ 0.03640542,  0.15138073, -0.40270562,  0.30485117,  0.18088813,
#        -0.55876656,  0.39855065,  0.10416556, -0.38618624,  0.23849314])
#
#
# Iteration # 69
# Eigenvalue: 1.195512
# Eigenvector: array([ 0.03460925,  0.15406267, -0.40303923,  0.30158671,  0.18480967,
#        -0.55949728,  0.39587555,  0.10702005, -0.38688548,  0.23796805])
#
#
# Iteration # 70
# Eigenvalue: 1.195385
# Eigenvector: array([ 0.0328154 ,  0.15673024, -0.40335071,  0.29831383,  0.18871235,
#        -0.56019666,  0.39318566,  0.10986228, -0.38756259,  0.23743157])
#
#
# Iteration # 71
# Eigenvalue: 1.195259
# Eigenvector: array([ 0.03102435,  0.15938282, -0.40364014,  0.29503348,  0.19259522,
#        -0.56086474,  0.39048182,  0.11269153, -0.38821756,  0.23688393])
#
#
# Iteration # 72
# Eigenvalue: 1.195133
# Eigenvector: array([ 0.02923657,  0.16201978, -0.40390761,  0.29174663,  0.19645738,
#        -0.56150158,  0.38776491,  0.11550714, -0.38885039,  0.23632536])
#
#
# Iteration # 73
# Eigenvalue: 1.195008
# Eigenvector: array([ 0.02745253,  0.16464054, -0.40415324,  0.28845425,  0.20029793,
#        -0.56210728,  0.38503577,  0.11830844, -0.38946108,  0.23575612])
#
#
# Iteration # 74
# Eigenvalue: 1.194884
# Eigenvector: array([ 0.02567268,  0.16724451, -0.40437715,  0.28515729,  0.204116  ,
#        -0.56268194,  0.38229528,  0.12109478, -0.39004966,  0.23517645])
#
#
# Iteration # 75
# Eigenvalue: 1.194761
# Eigenvector: array([ 0.02389749,  0.16983112, -0.40457949,  0.28185672,  0.20791074,
#        -0.5632257 ,  0.37954432,  0.12386553, -0.39061619,  0.23458662])
#
#
# Iteration # 76
# Eigenvalue: 1.194639
# Eigenvector: array([ 0.0221274 ,  0.17239985, -0.40476044,  0.27855351,  0.21168134,
#        -0.56373875,  0.37678376,  0.12662009, -0.39116074,  0.23398691])
#
#
# Iteration # 77
# Eigenvalue: 1.194517
# Eigenvector: array([ 0.02036286,  0.17495015, -0.40492017,  0.27524859,  0.21542701,
#        -0.56422126,  0.37401447,  0.12935785, -0.39168339,  0.23337758])
#
#
# Iteration # 78
# Eigenvalue: 1.194397
# Eigenvector: array([ 0.01860429,  0.17748153, -0.40505888,  0.27194294,  0.21914697,
#        -0.56467345,  0.37123734,  0.13207823, -0.39218425,  0.23275892])
#
#
# Iteration # 79
# Eigenvalue: 1.194277
# Eigenvector: array([ 0.01685211,  0.17999351, -0.40517679,  0.26863748,  0.22284049,
#        -0.56509557,  0.36845326,  0.13478069, -0.39266345,  0.23213122])
#
#
# Iteration # 80
# Eigenvalue: 1.194159
# Eigenvector: array([ 0.01510676,  0.1824856 , -0.40527414,  0.26533316,  0.22650685,
#        -0.56548788,  0.36566309,  0.13746468, -0.39312112,  0.23149477])
#
#
# Iteration # 81
# Eigenvalue: 1.194041
# Eigenvector: array([ 0.01336862,  0.18495738, -0.40535116,  0.2620309 ,  0.23014538,
#        -0.56585067,  0.36286772,  0.14012968, -0.39355742,  0.23084987])
#
#
# Iteration # 82
# Eigenvalue: 1.193925
# Eigenvector: array([ 0.01163811,  0.18740841, -0.40540812,  0.25873162,  0.23375542,
#        -0.56618424,  0.36006801,  0.14277519, -0.39397252,  0.23019682])
#
#
# Iteration # 83
# Eigenvalue: 1.193810
# Eigenvector: array([ 0.0099156 ,  0.1898383 , -0.4054453 ,  0.25543622,  0.23733634,
#        -0.56648891,  0.35726484,  0.14540074, -0.39436662,  0.22953593])
#
#
# Iteration # 84
# Eigenvalue: 1.193696
# Eigenvector: array([ 0.00820147,  0.19224665, -0.40546298,  0.2521456 ,  0.24088755,
#        -0.56676505,  0.35445907,  0.14800587, -0.39473991,  0.22886751])
#
#
# Iteration # 85
# Eigenvalue: 1.193583
# Eigenvector: array([ 0.00649609,  0.19463311, -0.40546145,  0.24886064,  0.24440848,
#        -0.567013  ,  0.35165155,  0.15059014, -0.39509261,  0.22819187])
#
#
# Iteration # 86
# Eigenvalue: 1.193472
# Eigenvector: array([ 0.00479982,  0.19699733, -0.40544104,  0.2455822 ,  0.2478986 ,
#        -0.56723316,  0.34884313,  0.15315313, -0.39542495,  0.22750931])
#
#
# Iteration # 87
# Eigenvalue: 1.193361
# Eigenvector: array([ 0.003113  ,  0.19933899, -0.40540206,  0.24231114,  0.25135739,
#        -0.56742593,  0.34603465,  0.15569445, -0.39573717,  0.22682017])
#
#
# Iteration # 88
# Eigenvalue: 1.193252
# Eigenvector: array([ 0.00143597,  0.20165779, -0.40534485,  0.23904829,  0.25478438,
#        -0.56759172,  0.34322693,  0.15821373, -0.39602953,  0.22612475])
#
#
# Iteration # 89
# Eigenvalue: 1.193144
# Eigenvector: array([-2.30961051e-04,  2.03953454e-01, -4.05269747e-01,  2.35794474e-01,
#         2.58179124e-01, -5.67730961e-01,  3.40420800e-01,  1.60710606e-01,
#        -3.96302300e-01,  2.25423371e-01])
#
#
# Iteration # 90
# Eigenvalue: 1.193038
# Eigenvector: array([-0.00188747,  0.20622572, -0.4051771 ,  0.23255049,  0.2615412 ,
#        -0.56784411,  0.33761706,  0.16318475, -0.39655575,  0.22471636])
#
#
# Iteration # 91
# Eigenvalue: 1.192933
# Eigenvector: array([-0.00353327,  0.20847436, -0.40506727,  0.22931713,  0.26487021,
#        -0.56793161,  0.33481651,  0.16563586, -0.39679018,  0.22400402])
#
#
# Iteration # 92
# Eigenvalue: 1.192829
# Eigenvector: array([-0.00516806,  0.21069914, -0.40494062,  0.22609516,  0.26816581,
#        -0.56799394,  0.33201992,  0.16806363, -0.39700588,  0.22328668])
#
#
# Iteration # 93
# Eigenvalue: 1.192727
# Eigenvector: array([-0.00679157,  0.21289986, -0.40479753,  0.22288533,  0.27142765,
#        -0.56803158,  0.32922806,  0.17046779, -0.39720316,  0.22256465])
#
#
# Iteration # 94
# Eigenvalue: 1.192626
# Eigenvector: array([-0.00840354,  0.21507636, -0.40463838,  0.21968836,  0.27465545,
#        -0.56804503,  0.32644169,  0.17284811, -0.39738233,  0.22183825])
#
#
# Iteration # 95
# Eigenvalue: 1.192527
# Eigenvector: array([-0.01000371,  0.21722847, -0.40446355,  0.21650496,  0.27784891,
#        -0.56803479,  0.32366155,  0.17520434, -0.39754372,  0.22110779])
#
#
# Iteration # 96
# Eigenvalue: 1.192429
# Eigenvector: array([-0.01159184,  0.21935605, -0.40427342,  0.21333583,  0.28100779,
#        -0.56800136,  0.32088835,  0.17753628, -0.39768767,  0.22037359])
#
#
# Iteration # 97
# Eigenvalue: 1.192332
# Eigenvector: array([-0.01316772,  0.22145897, -0.4040684 ,  0.21018163,  0.28413188,
#        -0.56794526,  0.3181228 ,  0.17984373, -0.3978145 ,  0.21963595])
#
#
# Iteration # 98
# Eigenvalue: 1.192237
# Eigenvector: array([-0.01473111,  0.22353714, -0.40384887,  0.20704301,  0.28722097,
#        -0.56786702,  0.31536559,  0.18212654, -0.39792456,  0.21889518])
#
#
# Iteration # 99
# Eigenvalue: 1.192143
# Eigenvector: array([-0.01628183,  0.22559048, -0.40361525,  0.20392059,  0.29027491,
#        -0.56776717,  0.31261739,  0.18438454, -0.39801819,  0.21815158])
#
#
# Iteration # 100
# Eigenvalue: 1.192051
# Eigenvector: array([-0.01781966,  0.2276189 , -0.40336793,  0.20081497,  0.29329354,
#        -0.56764624,  0.30987886,  0.1866176 , -0.39809576,  0.21740545])
#
#
# Inverse power method did not converge

# %% [markdown]
# This gives us an estimated shift of 1.2. Running again:

# %%
small_eval,s_evector = inverse_power(A2,1.2,300,tol=1E-6)
# Out:
# Iteration # 1
# Eigenvalue: 1.226050
# Eigenvector: array([ 0.228165  , -0.22182636, -0.18708891,  0.54061434, -0.33329426,
#        -0.23748331,  0.52567358, -0.25502007, -0.14854617,  0.20137123])
#
#
# Iteration # 2
# Eigenvalue: 1.205715
# Eigenvector: array([ 0.20334702, -0.16218771, -0.24369216,  0.53354801, -0.2647989 ,
#        -0.31167475,  0.53947759, -0.21157345, -0.19623749,  0.21614263])
#
#
# Iteration # 3
# Eigenvalue: 1.205698
# Eigenvector: array([ 0.21292231, -0.18737682, -0.22027024,  0.53842687, -0.29965421,
#        -0.27732959,  0.53559874, -0.23556887, -0.1711516 ,  0.2068227 ])
#
#
# Iteration # 4
# Eigenvalue: 1.205694
# Eigenvector: array([ 0.20846221, -0.17543694, -0.231608  ,  0.53644813, -0.28323636,
#        -0.29386348,  0.53779438, -0.22432543, -0.18316053,  0.21136574])
#
#
# Iteration # 5
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.21061451, -0.18114491, -0.22624406,  0.53746613, -0.29109208,
#        -0.28603408,  0.53682538, -0.22971021, -0.17746886,  0.20923257])
#
#
# Iteration # 6
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20959685, -0.17843396, -0.22880432,  0.53699883, -0.28736243,
#        -0.2897697 ,  0.53730379, -0.22715466, -0.18018352,  0.21025456])
#
#
# Iteration # 7
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.21008271, -0.17972549, -0.22758746,  0.53722513, -0.28913959,
#        -0.28799389,  0.53708   , -0.22837258, -0.17889282,  0.20976968])
#
#
# Iteration # 8
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20985182, -0.17911111, -0.22816697,  0.53711831, -0.28829426,
#        -0.28883953,  0.53718739, -0.22779331, -0.1795074 ,  0.2100008 ])
#
#
# Iteration # 9
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20996178, -0.17940358, -0.22789125,  0.53716935, -0.28869668,
#        -0.28843717,  0.53713648, -0.22806909, -0.17921497,  0.20989088])
#
#
# Iteration # 10
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20990947, -0.1792644 , -0.22802249,  0.53714511, -0.28850518,
#        -0.28862869,  0.53716075, -0.22793786, -0.17935416,  0.20994321])
#
#
# Iteration # 11
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20993437, -0.17933064, -0.22796003,  0.53715666, -0.28859633,
#        -0.28853755,  0.53714921, -0.22800032, -0.17928792,  0.20991831])
#
#
# Iteration # 12
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992252, -0.17929912, -0.22798976,  0.53715116, -0.28855295,
#        -0.28858093,  0.53715471, -0.22797059, -0.17931945,  0.20993016])
#
#
# Iteration # 13
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992816, -0.17931412, -0.22797561,  0.53715378, -0.2885736 ,
#        -0.28856028,  0.53715209, -0.22798474, -0.17930444,  0.20992452])
#
#
# Iteration # 14
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992547, -0.17930698, -0.22798235,  0.53715253, -0.28856377,
#        -0.28857011,  0.53715334, -0.22797801, -0.17931158,  0.20992721])
#
#
# Iteration # 15
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992675, -0.17931038, -0.22797914,  0.53715312, -0.28856845,
#        -0.28856543,  0.53715274, -0.22798121, -0.17930819,  0.20992593])
#
#
# Iteration # 16
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992614, -0.17930876, -0.22798067,  0.53715284, -0.28856622,
#        -0.28856766,  0.53715302, -0.22797968, -0.1793098 ,  0.20992654])
#
#
# Iteration # 17
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992643, -0.17930953, -0.22797994,  0.53715298, -0.28856728,
#        -0.2885666 ,  0.53715289, -0.22798041, -0.17930903,  0.20992625])
#
#
# Iteration # 18
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.2099263 , -0.17930916, -0.22798029,  0.53715291, -0.28856678,
#        -0.2885671 ,  0.53715295, -0.22798006, -0.1793094 ,  0.20992638])
#
#
# Iteration # 19
# Eigenvalue: 1.205693
# Eigenvector: array([ 0.20992636, -0.17930934, -0.22798012,  0.53715294, -0.28856702,
#        -0.28856686,  0.53715292, -0.22798023, -0.17930923,  0.20992632])

# %%
print("Smallest eigenvalue using inverse power iterations: %.6f"%small_eval)
print("Corresponding eigenvector:")
pp.pprint(s_evector)
# Out:
# Smallest eigenvalue using inverse power iterations: 1.205693
# Corresponding eigenvector:
# array([ 0.20992636, -0.17930934, -0.22798012,  0.53715294, -0.28856702,
#        -0.28856686,  0.53715292, -0.22798023, -0.17930923,  0.20992632])

# %% [markdown]
# Therefore, **inverse power method** now took 19 iterations to converge to the smallest eigenvalue, 1.205693.
# We use eigenvalue shifting for rapid convergence.
